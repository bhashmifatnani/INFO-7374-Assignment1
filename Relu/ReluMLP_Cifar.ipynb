# %% [markdown]
# # **CIFAR -10 DATASETS**
#
# The aim is to build a multilayer perecptron which will classify test images in 10 different categories(classes) using RELU as an activation function for hidden layer.

# %% [markdown]
# Steps followed to build a MLP
#
# 1.  Load libraries keras for accessing layers, activations and optimizers, matplotlib for plotting accuracies and numpy because the input data is stored in arrays
#
# 2. Load the cifar-10 datasets
#
# 3. Load model type, activations, layers to be used and optimizers which are used
#
# 4. Categorize the labels of test to 10 classes as our output will one of the 10 categories
#
# 5. Normalize Data
#
# 6. Start adding layers to model, compile the model, then fit the model where the training of data happens and finally in evaluate you test your model against the test data.
#
# 7. Plot your validation accuracy to check the accuracy of your model.
#
# 8. To modify your accuracies you tweak hyperparameters and repeat the process.

# %%
import keras
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 30s 0us/step

# %%
from keras.models import Sequential


from keras.layers import Activation, Dense, Dropout, Flatten

from keras.optimizers import rmsprop, SGD

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
# Transform images from (32,32,3) to 3072-dimensional vectors (32*32*3)

X_train = train_images.astype('float32')
X_test = test_images.astype('float32')

# Normalization of pixel values (to [0-1] range)

X_train /= 255
X_test /= 255

# %% [markdown]
# #Model one parameters
#
# Selected the values randomly which people generally start with, softmax as an output activation function because it gives the probabilities for each of the different output classes(best for mutliclass classification) all adding to one so the class with most probability is the output required or expected.
#
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 20
# 5.   batch_size = 128
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Relu"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#model fits the training data and labels and we mention our validation during model so it shows us the validation accuracy and loss

  finalModel1 = model.fit(X_train, train_labels, epochs=20, batch_size=128,validation_data=(X_test,test_labels))
  
#tells us the accuracy n loss of our function  
  
  history = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 8s 157us/step - loss: 8.9256 - acc: 0.1419 - val_loss: 2.1721 - val_acc: 0.2178
# Epoch 2/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.9430 - acc: 0.2953 - val_loss: 1.9310 - val_acc: 0.2936
# Epoch 3/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.8294 - acc: 0.3395 - val_loss: 1.7094 - val_acc: 0.3906
# Epoch 4/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.7700 - acc: 0.3676 - val_loss: 1.7039 - val_acc: 0.4119
# Epoch 5/20
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.7245 - acc: 0.3828 - val_loss: 1.6432 - val_acc: 0.4110
# Epoch 6/20
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.6956 - acc: 0.3969 - val_loss: 1.6588 - val_acc: 0.4084
# Epoch 7/20
# ...

# %%
  print('Test loss:', history[0])
  print('Test accuracy:', history[1])
# Out:
# Test loss: 1.5676398628234862
# Test accuracy: 0.4472

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(finalModel1.history['loss'])
plt.plot(finalModel1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model two parameters
#
# I saw my validation accuracy going good and high in model one so I continued with the same hyperparemeters except I increased the number of epochs
#
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 60
# 5.   batch_size = 128
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Relu"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel1 = model.fit(X_train, train_labels, epochs=60, batch_size=128, validation_data=(X_test,test_labels))
  
  history2 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/60
# 50000/50000 [==============================] - 9s 173us/step - loss: 6.3804 - acc: 0.1745 - val_loss: 1.8644 - val_acc: 0.3148
# Epoch 2/60
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.9143 - acc: 0.3064 - val_loss: 1.8797 - val_acc: 0.3315
# Epoch 3/60
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.8171 - acc: 0.3510 - val_loss: 1.7359 - val_acc: 0.3790
# Epoch 4/60
# 50000/50000 [==============================] - 7s 147us/step - loss: 1.7581 - acc: 0.3713 - val_loss: 1.7019 - val_acc: 0.3801
# Epoch 5/60
# 50000/50000 [==============================] - 7s 146us/step - loss: 1.7231 - acc: 0.3856 - val_loss: 1.6971 - val_acc: 0.4077
# Epoch 6/60
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.6913 - acc: 0.3973 - val_loss: 1.6276 - val_acc: 0.4032
# Epoch 7/60
# ...

# %%
  print('Test loss:', history2[0])
  print('Test accuracy:', history2[1])
# Out:
# Test loss: 1.4414915546417237
# Test accuracy: 0.4904

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(finalModel1.history['loss'])
plt.plot(finalModel1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model three parameters
#
# The model 2 accuracy improved but, I want reduce batch size as it learns slowly, captures details and produce better results.
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 30
# 5.   batch_size = 64
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Relu"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel2 = model.fit(X_train, train_labels, epochs=30, batch_size=64, verbose=1, validation_data=(X_test,test_labels))
  
  history3 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 13s 266us/step - loss: 5.5992 - acc: 0.2055 - val_loss: 1.8725 - val_acc: 0.3421
# Epoch 2/30
# 50000/50000 [==============================] - 12s 247us/step - loss: 1.8671 - acc: 0.3286 - val_loss: 1.8107 - val_acc: 0.3511
# Epoch 3/30
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.7976 - acc: 0.3563 - val_loss: 1.7583 - val_acc: 0.3711
# Epoch 4/30
# 50000/50000 [==============================] - 12s 247us/step - loss: 1.7661 - acc: 0.3737 - val_loss: 1.7177 - val_acc: 0.3989
# Epoch 5/30
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.7389 - acc: 0.3790 - val_loss: 1.8294 - val_acc: 0.3567
# Epoch 6/30
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.7306 - acc: 0.3875 - val_loss: 1.7905 - val_acc: 0.3837
# Epoch 7/30
# ...

# %%
  print('Test loss:', history3[0])
  print('Test accuracy:', history3[1])
# Out:
# Test loss: 1.595986099243164
# Test accuracy: 0.4494

# %%
# summarize history for accuracy
plt.plot(finalModel2.history['acc'])
plt.plot(finalModel2.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(finalModel2.history['loss'])
plt.plot(finalModel2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model four parameters
#
# It reduced so minimizing the batch size didn't make a dfference in comparison to the model one.
# So, to improve accuracy I tried Stochastic gardient descent optimizer to get optimal accuracy.
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 20
# 5.   batch_size = 64
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Relu"
# 8.   optimization function =''SGD""

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

lrrate = 0.01
epochs = 20
decay = lrrate/epochs

sgd = SGD(lr=lrrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(optimizer=sgd,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel3 = model.fit(X_train, train_labels, epochs=20, batch_size=64, verbose=1, validation_data=(X_test,test_labels))
  
  history4 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.8905 - acc: 0.3113 - val_loss: 1.7064 - val_acc: 0.3862
# Epoch 2/20
# 50000/50000 [==============================] - 9s 184us/step - loss: 1.7148 - acc: 0.3844 - val_loss: 1.6242 - val_acc: 0.4246
# Epoch 3/20
# 50000/50000 [==============================] - 9s 181us/step - loss: 1.6277 - acc: 0.4185 - val_loss: 1.5538 - val_acc: 0.4463
# Epoch 4/20
# 50000/50000 [==============================] - 9s 182us/step - loss: 1.5638 - acc: 0.4396 - val_loss: 1.5149 - val_acc: 0.4615
# Epoch 5/20
# 50000/50000 [==============================] - 9s 180us/step - loss: 1.5176 - acc: 0.4571 - val_loss: 1.4835 - val_acc: 0.4733
# Epoch 6/20
# 50000/50000 [==============================] - 9s 180us/step - loss: 1.4766 - acc: 0.4687 - val_loss: 1.4146 - val_acc: 0.4965
# Epoch 7/20
# ...

# %%
  print('Test loss:', history4[0])
  print('Test accuracy:', history4[1])
# Out:
# Test loss: 1.2785604661941528
# Test accuracy: 0.5402

# %%
# summarize history for accuracy
plt.plot(finalModel3.history['acc'])
plt.plot(finalModel3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel3.history['loss'])
plt.plot(finalModel3.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model five parameters
#
# 54% accuracy that's a leap of by 10%. Assuming the model four to be better I increased the no of epochs to let the data to train for longer run as compared to the above model.
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 75
# 5.   batch_size = 64
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Relu"
# 8.   optimization function =''SGD""

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(10, activation='softmax'))

lrrate = 0.01
epochs = 150
decay = lrrate/epochs

sgd = SGD(lr=lrrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(optimizer=sgd,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel4 = model.fit(X_train, train_labels, epochs=150, batch_size=64, validation_data=(X_test,test_labels))
  
  history5 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/150
# 50000/50000 [==============================] - 10s 199us/step - loss: 2.1738 - acc: 0.1817 - val_loss: 2.0032 - val_acc: 0.2814
# Epoch 2/150
# 50000/50000 [==============================] - 8s 161us/step - loss: 2.0558 - acc: 0.2250 - val_loss: 1.9691 - val_acc: 0.2693
# Epoch 3/150
# 50000/50000 [==============================] - 8s 161us/step - loss: 2.0141 - acc: 0.2449 - val_loss: 1.9949 - val_acc: 0.2657
# Epoch 4/150
# 50000/50000 [==============================] - 8s 161us/step - loss: 1.9786 - acc: 0.2632 - val_loss: 1.9661 - val_acc: 0.3035
# Epoch 5/150
# 50000/50000 [==============================] - 8s 161us/step - loss: 1.9474 - acc: 0.2795 - val_loss: 1.9446 - val_acc: 0.2887
# Epoch 6/150
# 50000/50000 [==============================] - 8s 161us/step - loss: 1.9279 - acc: 0.2874 - val_loss: 1.9140 - val_acc: 0.3275
# Epoch 7/150
# ...

# %%
  print('Test loss:', history5[0])
  print('Test accuracy:', history5[1])
# Out:
# Test loss: 1.3786552757263184
# Test accuracy: 0.5116

# %%
# summarize history for accuracy
plt.plot(finalModel4.history['acc'])
plt.plot(finalModel4.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel4.history['loss'])
plt.plot(finalModel4.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model six parameters
#
# Assumption for the model 5 failed. So, now I tried totally not relevant hyperparemeters to check how Sigmoid function works with relu.
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units = 512, 256
# 3.   output_num_units = 10
# 4.   epochs = 20
# 5.   batch_size = 64
# 6.   output activation_function = 'Sigmoid'
# 7.   layer activation_function = "Relu"
# 8.   optimization function =''rmsprop""

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))


model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='sigmoid'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel5 = model.fit(X_train, train_labels, epochs=20, batch_size=64, validation_data=(X_test,test_labels))
  
  history6 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 8s 154us/step - loss: 2.3262 - acc: 0.1069 - val_loss: 2.4945 - val_acc: 0.1156
# Epoch 2/20
# 50000/50000 [==============================] - 7s 135us/step - loss: 2.3322 - acc: 0.1054 - val_loss: 2.3967 - val_acc: 0.1373
# Epoch 3/20
# 50000/50000 [==============================] - 7s 134us/step - loss: 2.3507 - acc: 0.1046 - val_loss: 2.3013 - val_acc: 0.1002
# Epoch 4/20
# 50000/50000 [==============================] - 7s 136us/step - loss: 2.3490 - acc: 0.1024 - val_loss: 2.3024 - val_acc: 0.1000
# Epoch 5/20
# 50000/50000 [==============================] - 7s 135us/step - loss: 2.3885 - acc: 0.1013 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 6/20
# 50000/50000 [==============================] - 7s 135us/step - loss: 2.3927 - acc: 0.1011 - val_loss: 2.3022 - val_acc: 0.1002
# Epoch 7/20
# ...

# %%
  print('Test loss:', history6[0])
  print('Test accuracy:', history6[1])
# Out:
# Test loss: 1.1920930376163597e-07
# Test accuracy: 0.1

# %%
# summarize history for accuracy
plt.plot(finalModel5.history['acc'])
plt.plot(finalModel5.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel5.history['loss'])
plt.plot(finalModel5.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model six parameters
#
# Model 5 got an accuracy which is 0.1 which means I have something wrong with my hyperparametrs so I modified them increasing the batch size and epochs.
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units = 512, 256
# 3.   output_num_units = 10
# 4.   epochs = 30
# 5.   batch_size = 128
# 6.   output activation_function = 'Sigmoid'
# 7.   layer activation_function = "Relu"
# 8.   optimization function =''rmsprop""

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))



model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))


model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalMode = model.fit(X_train, train_labels, epochs=30, batch_size=128, validation_data=(X_test,test_labels))
  
  histo= model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 8s 156us/step - loss: 2.3302 - acc: 0.1093 - val_loss: 2.3090 - val_acc: 0.1033
# Epoch 2/30
# 50000/50000 [==============================] - 8s 154us/step - loss: 2.4117 - acc: 0.1143 - val_loss: 2.3172 - val_acc: 0.1052
# Epoch 3/30
# 50000/50000 [==============================] - 8s 154us/step - loss: 2.3164 - acc: 0.1042 - val_loss: 2.3128 - val_acc: 0.1046
# Epoch 4/30
# 50000/50000 [==============================] - 8s 155us/step - loss: 2.3303 - acc: 0.1076 - val_loss: 2.3083 - val_acc: 0.1030
# Epoch 5/30
# 50000/50000 [==============================] - 8s 153us/step - loss: 2.3069 - acc: 0.1061 - val_loss: 2.3122 - val_acc: 0.1054
# Epoch 6/30
# 50000/50000 [==============================] - 8s 155us/step - loss: 2.3112 - acc: 0.1040 - val_loss: 2.3088 - val_acc: 0.1027
# Epoch 7/30
# ...

# %%
  print('Test loss:', histo[0])
  print('Test accuracy:', histo[1])
# Out:
# Test loss: 2.3072106422424317
# Test accuracy: 0.1079

# %%
# summarize history for accuracy
plt.plot(finalMode.history['acc'])
plt.plot(finalMode.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel4.history['loss'])
plt.plot(finalModel4.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# The accuracy did increase but hyperparameters still needs a lot of change.
# I also tried adding dense layers with more number of nodes  where test accuracy was very low comparison to the training data accuracy

# %% [markdown]
# **Conclusion**
#
# Running different combinations of hyperparameter values for Relu the best validation accuracy I got is 54% so model 4 is the best amongst all.
