# %% [markdown]
# # **CIFAR -10 DATASETS**
#
# The aim is to build a multilayer perecptron which will classify test images in 10 different categories(classes) using Sigmoid as an activation function for hidden layer.

# %% [markdown]
# Steps followed to build a MLP
#
# 1.  Load libraries keras for accessing layers, activations and optimizers, matplotlib for plotting accuracies and numpy because the input data is stored in arrays
#
# 2. Load the cifar-10 datasets
#
# 3. Load model type, activations, layers to be used and optimizers which are used
#
# 4. Categorize the labels of test to 10 classes as our output will one of the 10 categories
#
# 5. Normalize Data
#
# 6. Start adding layers to model, compile the model, then fit the model where the training of data happens and finally in evaluate you test your model against the test data.
#
# 7. Plot your validation accuracy to check the accuracy of your model.
#
# 8. To modify your accuracies you tweak hyperparameters and repeat the process.

# %%
import keras
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# %%
from keras.models import Sequential


from keras.layers import Activation, Dense, Dropout, Flatten

from keras.optimizers import rmsprop, SGD

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
# Transform images from (32,32,3) to 3072-dimensional vectors (32*32*3)

X_train = train_images.astype('float32')
X_test = test_images.astype('float32')

# Normalization of pixel values (to [0-1] range)

X_train /= 255
X_test /= 255

# %% [markdown]
# #Model one parameters
#
# Random hyperparamters what generally is practised
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 10
# 5.   batch_size = 128
# 6.   output activation_function = 'Relu'
# 7.   layer activation_function = "sigmoid"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  history1 = model.fit(X_train, train_labels, epochs=10, batch_size=128, validation_data=(X_test,test_labels))
  
  score1 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 14s 280us/step - loss: 6.1382 - acc: 0.1594 - val_loss: 6.0329 - val_acc: 0.2012
# Epoch 2/10
# 50000/50000 [==============================] - 12s 231us/step - loss: 6.0690 - acc: 0.1996 - val_loss: 6.0358 - val_acc: 0.2085
# Epoch 3/10
# 50000/50000 [==============================] - 12s 230us/step - loss: 6.0490 - acc: 0.2236 - val_loss: 6.0269 - val_acc: 0.2031
# Epoch 4/10
# 50000/50000 [==============================] - 12s 241us/step - loss: 6.0148 - acc: 0.2434 - val_loss: 5.9422 - val_acc: 0.2726
# Epoch 5/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 5.9998 - acc: 0.2592 - val_loss: 5.9736 - val_acc: 0.2784
# Epoch 6/10
# 50000/50000 [==============================] - 11s 230us/step - loss: 6.0044 - acc: 0.2670 - val_loss: 6.0082 - val_acc: 0.2478
# Epoch 7/10
# ...

# %%
  print('Test loss:', score1[0])
  print('Test accuracy:', score1[1])
# Out:
# Test loss: 6.050641844940186
# Test accuracy: 0.2718

# %%
# summarize history for accuracy
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model two parameters
#
# increased the epochs and removed one layer.
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units = 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 20
# 5.   batch_size = 128
# 6.   output activation_function = 'Relu'
# 7.   layer activation_function = "sigmoid"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(1024, activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  history2 = model.fit(X_train, train_labels, epochs=20, batch_size=128, validation_data=(X_test,test_labels))
  
  score2 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 10s 194us/step - loss: 2.2022 - acc: 0.2052 - val_loss: 2.2850 - val_acc: 0.2271
# Epoch 2/20
# 50000/50000 [==============================] - 9s 184us/step - loss: 2.0967 - acc: 0.2854 - val_loss: 2.4653 - val_acc: 0.2057
# Epoch 3/20
# 50000/50000 [==============================] - 9s 176us/step - loss: 2.0563 - acc: 0.3062 - val_loss: 1.9398 - val_acc: 0.3415
# Epoch 4/20
# 50000/50000 [==============================] - 9s 177us/step - loss: 2.0382 - acc: 0.3291 - val_loss: 1.9797 - val_acc: 0.2996
# Epoch 5/20
# 50000/50000 [==============================] - 9s 170us/step - loss: 2.0234 - acc: 0.3337 - val_loss: 2.0914 - val_acc: 0.2377
# Epoch 6/20
# 50000/50000 [==============================] - 9s 180us/step - loss: 2.0234 - acc: 0.3431 - val_loss: 1.8953 - val_acc: 0.3836
# Epoch 7/20
# ...

# %%
  print('Test loss:', score2[0])
  print('Test accuracy:', score2[1])
# Out:
# Test loss: 1.8983733242034913
# Test accuracy: 0.4051

# %%
# summarize history for accuracy
plt.plot(history2.history['acc'])
plt.plot(history2.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model three parameters
#
# Model 2 hyperparameters did improve the accuracy so lets reduce the layers to reduce complexity and reduce computing time and also reduce batch size to cover detailed feature and yes also update the output activation as softmax
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units =  512, 256
# 3.   output_num_units = 10
# 4.   epochs = 20
# 5.   batch_size = 64
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "Sigmoid"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(256,activation='sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  history3 = model.fit(X_train, train_labels, epochs=20, batch_size=64, validation_data=(X_test,test_labels))
  
  score3 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 15s 305us/step - loss: 1.9203 - acc: 0.3025 - val_loss: 1.9686 - val_acc: 0.2877
# Epoch 2/20
# 50000/50000 [==============================] - 15s 306us/step - loss: 1.7635 - acc: 0.3656 - val_loss: 1.7334 - val_acc: 0.3627
# Epoch 3/20
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.6996 - acc: 0.3906 - val_loss: 1.8462 - val_acc: 0.3703
# Epoch 4/20
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.6590 - acc: 0.4076 - val_loss: 1.8206 - val_acc: 0.3435
# Epoch 5/20
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.6278 - acc: 0.4221 - val_loss: 1.7816 - val_acc: 0.3914
# Epoch 6/20
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.6094 - acc: 0.4266 - val_loss: 1.5889 - val_acc: 0.4396
# Epoch 7/20
# ...

# %%
  print('Test loss:', score3[0])
  print('Test accuracy:', score3[1])
# Out:
# Test loss: 1.5259342922210692
# Test accuracy: 0.4565

# %%
# summarize history for accuracy
plt.plot(history3.history['acc'])
plt.plot(history3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model four parameters
#
# Not much difference, so I added one more layer and increased the batch size
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 1024, 512, 256
# 3.   output_num_units = 10
# 4.   epochs = 40
# 5.   batch_size = 128
# 6.   output activation_function = 'softmax'
# 7.   layer activation_function = "sigmoid"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(1024, activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(512,activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(256,activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  history4 = model.fit(X_train, train_labels, epochs=40, batch_size=128, validation_data=(X_test,test_labels))
  
  score4 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 6s 115us/step - loss: 2.1773 - acc: 0.1716 - val_loss: 2.0101 - val_acc: 0.2717
# Epoch 2/40
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.9801 - acc: 0.2729 - val_loss: 1.9075 - val_acc: 0.3139
# Epoch 3/40
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.9096 - acc: 0.3040 - val_loss: 1.8219 - val_acc: 0.3403
# Epoch 4/40
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.8702 - acc: 0.3232 - val_loss: 1.7662 - val_acc: 0.3650
# Epoch 5/40
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.8448 - acc: 0.3344 - val_loss: 1.7358 - val_acc: 0.3711
# Epoch 6/40
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.8308 - acc: 0.3395 - val_loss: 1.7804 - val_acc: 0.3571
# Epoch 7/40
# ...

# %%
  print('Test loss:', score4[0])
  print('Test accuracy:', score4[1])
# Out:
# Test loss: 1.562571697616577
# Test accuracy: 0.4339

# %%
# summarize history for accuracy
plt.plot(history4.history['acc'])
plt.plot(history4.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model five parameters
#
# model 4 didnot work so lets try reducing the batch size, epochs.
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 1024, 512, 256
# 3.   output_num_units = 10
# 4.   epochs = 10
# 5.   batch_size = 64
# 6.   output activation_function = 'sigmoid'
# 7.   layer activation_function = "sigmoid"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(1024, activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(512,activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(256,activation='sigmoid'))
model.add(Dropout(0.6))

model.add(Dense(10, activation='sigmoid'))


lrrate = 0.01
epochs = 10
decay = lrrate/epochs

sgd = SGD(lr=lrrate, momentum=0.9, decay=decay, nesterov=False)


model.compile(optimizer=sgd,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  history5 = model.fit(X_train, train_labels, epochs=10, batch_size=64, validation_data=(X_test,test_labels))
  
  score5 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 13s 264us/step - loss: 2.3028 - acc: 0.1005 - val_loss: 2.3025 - val_acc: 0.0999
# Epoch 2/10
# 50000/50000 [==============================] - 13s 268us/step - loss: 2.3026 - acc: 0.1024 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 3/10
# 50000/50000 [==============================] - 13s 269us/step - loss: 2.3029 - acc: 0.1010 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 4/10
# 50000/50000 [==============================] - 13s 266us/step - loss: 2.3027 - acc: 0.1011 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 5/10
# 50000/50000 [==============================] - 13s 269us/step - loss: 2.3026 - acc: 0.1013 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 6/10
# 50000/50000 [==============================] - 13s 262us/step - loss: 2.3029 - acc: 0.1003 - val_loss: 2.3025 - val_acc: 0.1000
# Epoch 7/10
# ...

# %%
  print('Test loss:', score5[0])
  print('Test accuracy:', score5[1])
# Out:
# Test loss: 2.30249486618042
# Test accuracy: 0.102

# %%
# summarize history for accuracy
plt.plot(history3.history['acc'])
plt.plot(history3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Model 5 failed completely so need to keep changing the hyperparameter

# %% [markdown]
# **Conclusion**
#
# Running different combinations of hyperparameter values for Sigmoid the best validation accuracy I got is 45% so model 3 is the best amongst all.
