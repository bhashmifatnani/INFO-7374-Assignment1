# %% [markdown]
# # **CIFAR -10 DATASETS**
#
# The aim is to build a multilayer perecptron which will classify test images in 10 different categories(classes) using SOFTMAX as an activation function for hidden layer.

# %% [markdown]
# Steps followed to build a MLP
#
# 1.  Load libraries keras for accessing layers, activations and optimizers, matplotlib for plotting accuracies and numpy because the input data is stored in arrays
#
# 2. Load the cifar-10 datasets
#
# 3. Load model type, activations, layers to be used and optimizers which are used
#
# 4. Categorize the labels of test to 10 classes as our output will one of the 10 categories
#
# 5. Normalize Data
#
# 6. Start adding layers to model, compile the model, then fit the model where the training of data happens and finally in evaluate you test your model against the test data.
#
# 7. Plot your validation accuracy to check the accuracy of your model.
#
# 8. To modify your accuracies you tweak hyperparameters and repeat the process.

# %%
import keras
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.datasets import cifar10

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# %%
from keras.models import Sequential


from keras.layers import Activation, Dense, Dropout, Flatten

from keras.optimizers import rmsprop, SGD

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
# Transform images from (32,32,3) to 3072-dimensional vectors (32*32*3)

X_train = train_images.astype('float32')
X_test = test_images.astype('float32')

# Normalization of pixel values (to [0-1] range)

X_train /= 255
X_test /= 255

# %% [markdown]
# #Model one parameters
#
# Selected the values randomly which people generally start with, softmax as an output activation function because it gives the probabilities for each of the different output classes(best for mutliclass classification) all adding to one so the class with most probability is the output required or expected.
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 15
# 5.   batch_size = 128
# 6.   output activation_function = 'Softmax'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel1 = model.fit(X_train, train_labels, epochs=15, batch_size=128, validation_data=(X_test,test_labels))
  
  history1 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 13s 266us/step - loss: 2.3028 - acc: 0.0978 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 2/15
# 50000/50000 [==============================] - 13s 252us/step - loss: 2.3028 - acc: 0.1001 - val_loss: 2.3027 - val_acc: 0.1000
# Epoch 3/15
# 50000/50000 [==============================] - 13s 255us/step - loss: 2.3028 - acc: 0.1010 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 4/15
# 50000/50000 [==============================] - 12s 241us/step - loss: 2.3028 - acc: 0.0982 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 5/15
# 50000/50000 [==============================] - 11s 221us/step - loss: 2.3028 - acc: 0.0982 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 6/15
# 50000/50000 [==============================] - 12s 246us/step - loss: 2.3028 - acc: 0.0973 - val_loss: 2.3026 - val_acc: 0.1000
# Epoch 7/15
# ...

# %%
  print('Test loss:', history1[0])
  print('Test accuracy:', history1[1])
# Out:
# Test loss: 2.3025643783569336
# Test accuracy: 0.1

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model two parameters
#
# model one failed completely so I changed my output activation to be Relu as my hidden layer has softmax activations and using same for output might result in vague probabilities again this is an assumption
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 2048, 1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 30
# 5.   batch_size = 128
# 6.   output activation_function = 'relu'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(2048, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(1024, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel0 = model.fit(X_train, train_labels, epochs=30, batch_size=128, validation_data=(X_test,test_labels))
  
  history0 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 11s 219us/step - loss: 6.3889 - acc: 0.0987 - val_loss: 6.1989 - val_acc: 0.1000
# Epoch 2/30
# 50000/50000 [==============================] - 8s 165us/step - loss: 6.1743 - acc: 0.1287 - val_loss: 6.0999 - val_acc: 0.1623
# Epoch 3/30
# 50000/50000 [==============================] - 8s 166us/step - loss: 6.1145 - acc: 0.1522 - val_loss: 6.0536 - val_acc: 0.1724
# Epoch 4/30
# 50000/50000 [==============================] - 8s 166us/step - loss: 6.1015 - acc: 0.1489 - val_loss: 6.0249 - val_acc: 0.1644
# Epoch 5/30
# 50000/50000 [==============================] - 8s 164us/step - loss: 6.0871 - acc: 0.1524 - val_loss: 6.0280 - val_acc: 0.1650
# Epoch 6/30
# 50000/50000 [==============================] - 8s 169us/step - loss: 6.0844 - acc: 0.1501 - val_loss: 6.0064 - val_acc: 0.1780
# Epoch 7/30
# ...

# %%
  print('Test loss:', history0[0])
  print('Test accuracy:', history0[1])
# Out:
# Test loss: 5.970903760528564
# Test accuracy: 0.1803

# %%
# summarize history for accuracy
plt.plot(finalModel0.history['acc'])
plt.plot(finalModel0.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel0.history['acc'])
plt.plot(finalModel0.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model three parameters
#
# acuracy did move a little bit ofcourse the hyperparemeters are not perfect but changing the output activation did help a perecent or so to push up the accuracy. Let's reduce the batch size to capture details as it learns slow and improve accuracy
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units =1024, 512
# 3.   output_num_units = 10
# 4.   epochs = 45
# 5.   batch_size = 64
# 6.   output activation_function = 'relu'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(1024, activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel1 = model.fit(X_train, train_labels, epochs=45, batch_size=64, validation_data=(X_test,test_labels))
  
  history1 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/45
# 50000/50000 [==============================] - 10s 203us/step - loss: 7.5144 - acc: 0.1417 - val_loss: 7.4073 - val_acc: 0.1564
# Epoch 2/45
# 50000/50000 [==============================] - 8s 163us/step - loss: 7.4574 - acc: 0.1570 - val_loss: 7.3941 - val_acc: 0.1921
# Epoch 3/45
# 50000/50000 [==============================] - 7s 146us/step - loss: 7.4397 - acc: 0.1792 - val_loss: 7.4315 - val_acc: 0.1913
# Epoch 4/45
# 50000/50000 [==============================] - 8s 150us/step - loss: 7.4399 - acc: 0.1910 - val_loss: 7.3519 - val_acc: 0.2188
# Epoch 5/45
# 50000/50000 [==============================] - 7s 141us/step - loss: 7.4111 - acc: 0.1999 - val_loss: 7.3560 - val_acc: 0.2254
# Epoch 6/45
# 50000/50000 [==============================] - 7s 138us/step - loss: 7.3996 - acc: 0.2093 - val_loss: 7.3683 - val_acc: 0.2180
# Epoch 7/45
# ...

# %%
print('Test loss:', history1[0])
print('Test accuracy:', history1[1])
# Out:
# Test loss: 7.396595338439941
# Test accuracy: 0.2484

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel1.history['acc'])
plt.plot(finalModel1.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model four parameters
#
# Model 3 did improve the accuracy than model two so now I tried to decrease the layers and batch size to check if I get increase in the accuracy.
#
# 1.   Hidden layers = 1
# 2.   hidden_num_units = 512
# 3.   output_num_units = 10
# 4.   epochs = 75
# 5.   batch_size = 32
# 6.   output activation_function = 'relu'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))


model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel3 = model.fit(X_train, train_labels, epochs=75, batch_size=32, validation_data=(X_test,test_labels))
  
  history3 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/75
# 50000/50000 [==============================] - 12s 243us/step - loss: 5.2072 - acc: 0.1035 - val_loss: 6.2266 - val_acc: 0.1248
# Epoch 2/75
# 50000/50000 [==============================] - 12s 234us/step - loss: 5.5981 - acc: 0.1077 - val_loss: 6.2165 - val_acc: 0.1172
# Epoch 3/75
# 50000/50000 [==============================] - 12s 234us/step - loss: 6.4294 - acc: 0.1273 - val_loss: 7.6018 - val_acc: 0.1673
# Epoch 4/75
# 50000/50000 [==============================] - 12s 233us/step - loss: 5.5552 - acc: 0.1476 - val_loss: 5.8187 - val_acc: 0.1863
# Epoch 5/75
# 50000/50000 [==============================] - 11s 230us/step - loss: 4.3899 - acc: 0.1499 - val_loss: 3.9752 - val_acc: 0.1789
# Epoch 6/75
# 50000/50000 [==============================] - 12s 235us/step - loss: 3.8525 - acc: 0.1414 - val_loss: 3.7420 - val_acc: 0.1438
# Epoch 7/75
# ...

# %%
print('Test loss:', history3[0])
print('Test accuracy:', history3[1])
# Out:
# Test loss: 4.8533915969848636
# Test accuracy: 0.1727

# %%
# summarize history for accuracy
plt.plot(finalModel3.history['acc'])
plt.plot(finalModel3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel3.history['acc'])
plt.plot(finalModel3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model four parameters
#
# Reducing layers didnot work so adding a layer and trying tanh as an output activation function.
#
# 1.   Hidden layers = 2
# 2.   hidden_num_units = 512, 512
# 3.   output_num_units = 10
# 4.   epochs = 15
# 5.   batch_size = 64
# 6.   output activation_function = 'tanh'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))



model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))
model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))


model.add(Dense(10, activation='tanh'))


lrrate = 0.01
epochs = 15
decay = lrrate/epochs

sgd = SGD(lr=lrrate, momentum=0.9, decay=decay, nesterov=False)

model.compile(optimizer=sgd,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel4 = model.fit(X_train, train_labels, epochs=15, batch_size=64, validation_data=(X_test,test_labels))
  
  history4 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 2/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 3/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 4/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 5/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 6/15
# 50000/50000 [==============================] - 5s 109us/step - loss: 4.6570 - acc: 0.1000 - val_loss: 4.6570 - val_acc: 0.1000
# Epoch 7/15
# ...

# %%
print('Test loss:', history4[0])
print('Test accuracy:', history4[1])
# Out:
# Test loss: 4.65702431564331
# Test accuracy: 0.1

# %%
# summarize history for accuracy
plt.plot(finalModel4.history['acc'])
plt.plot(finalModel4.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel4.history['acc'])
plt.plot(finalModel4.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #Model five parameters
#
# model 4 failed so to change I used sigmoid as output activation function
#
# 1.   Hidden layers = 3
# 2.   hidden_num_units = 1024, 512, 256
# 3.   output_num_units = 10
# 4.   epochs = 40
# 5.   batch_size = 64
# 6.   output activation_function = 'sigmoid'
# 7.   layer activation_function = "softmax"

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))



model.add(Dense(1024,activation='softmax'))
model.add(Dropout(0.2))
model.add(Dense(512,activation='softmax'))
model.add(Dropout(0.2))
model.add(Dense(256,activation='softmax'))
model.add(Dropout(0.2))


model.add(Dense(10, activation='sigmoid'))




model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
#def fitTheModel():
  
  finalModel5 = model.fit(X_train, train_labels, epochs=40, batch_size=64, validation_data=(X_test,test_labels))
  
  history5 = model.evaluate(X_test,test_labels)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 9s 171us/step - loss: 2.0774 - acc: 0.1875 - val_loss: 2.0996 - val_acc: 0.1798
# Epoch 2/40
# 50000/50000 [==============================] - 9s 172us/step - loss: 2.0674 - acc: 0.1993 - val_loss: 2.0170 - val_acc: 0.2209
# Epoch 3/40
# 50000/50000 [==============================] - 9s 179us/step - loss: 2.0639 - acc: 0.2053 - val_loss: 2.0124 - val_acc: 0.2327
# Epoch 4/40
# 50000/50000 [==============================] - 9s 173us/step - loss: 2.0530 - acc: 0.2080 - val_loss: 2.0063 - val_acc: 0.2307
# Epoch 5/40
# 50000/50000 [==============================] - 9s 173us/step - loss: 2.0503 - acc: 0.2129 - val_loss: 1.9938 - val_acc: 0.2456
# Epoch 6/40
# 50000/50000 [==============================] - 9s 173us/step - loss: 2.0429 - acc: 0.2157 - val_loss: 2.1015 - val_acc: 0.2268
# Epoch 7/40
# ...

# %%
print('Test loss:', history5[0])
print('Test accuracy:', history5[1])
# Out:
# Test loss: 1.9812362957000733
# Test accuracy: 0.2702

# %%
# summarize history for accuracy
plt.plot(finalModel5.history['acc'])
plt.plot(finalModel5.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(finalModel5.history['acc'])
plt.plot(finalModel5.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Not great accuracy but better than other models

# %% [markdown]
# **Conclusion**
#
# Running different combinations of hyperparameter values for Softmax the best validation accuracy I got is 27% so model 5 is the best amongst all.
